# %%
from extract.extract import *
import pandas as pd

# %%
billboards = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard200.csv')
# Out:
# C:\Users\ulasz\AppData\Local\Temp\ipykernel_5532\4118517050.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   billboards = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard200.csv')

# %%
billboards.head()
# Out:
#          Date                                         Song  \
# 0  1963-08-14                       Days Of Wine And Roses
# 1  1963-08-14  Little Stevie Wonder/The 12 Year Old Genius
# 2  1963-08-14                              West Side Story
# 3  1963-08-14                                     (Moving)
# 4  1963-08-14                          Trini Lopez At PJ's
#
#                Artist  Rank Last Week  Peak Position Weeks in Charts  \
# 0       Andy Williams     1         1              1               -
# 1       Stevie Wonder     2         2              1               -
# 2          Soundtrack     3         3              1               -
# 3  Peter| Paul & Mary     4         4              1               -
# 4         Trini Lopez     5         5              1               -
#
#                                            Image URL
# 0  https://charts-static.billboard.com/img/1963/0...
# 1  https://charts-static.billboard.com/img/1963/0...
# 2  https://charts-static.billboard.com/img/1963/0...
# 3                                                  #
# 4  https://charts-static.billboard.com/img/1963/0...

# %%
billboard = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\billboard200.csv')
hot100 = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\hot100.csv')
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_17764\782904980.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   billboard = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\billboard200.csv')

# %%
output = extract_multiple_sources(
    [r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\charts_viral50.csv'],
    r'.\output',
    enrich=True
)
# Out:
# Processed 0/30 tracks for Spotify enrichment
# Processed 10/30 tracks for Spotify enrichment
# Processed 20/30 tracks for Spotify enrichment
# Skipping MusicBrainz enrichment for cached artist: SyKo
# Skipping MusicBrainz enrichment for cached artist: Paty Cantú, Juhn
# Skipping MusicBrainz enrichment for cached artist: BMW KENNY
# Skipping MusicBrainz enrichment for cached artist: YSY A, CLUB HATS
# Skipping MusicBrainz enrichment for cached artist: YSY A, Yesan 雪山
# Skipping MusicBrainz enrichment for cached artist: YSY A, Bizarrap
# Artist not found for (G)I-DLE
# Skipping MusicBrainz enrichment for cached artist: Jack Back
# Skipping MusicBrainz enrichment for cached artist: Aretha Franklin
# Skipping MusicBrainz enrichment for cached artist: Covi Quintana
# Skipping MusicBrainz enrichment for cached artist: Aitana, Cali Y El Dandee
# Skipping MusicBrainz enrichment for cached artist: Taylor Swift
# Data saved to .\output\raw_charts_viral50_20250604_142636.csv, records: 30

# %%
processed_data = pd.read_csv(r'.\output\raw_charts_viral50_20250604_142636.csv')

# %%
processed_data
# Out:
#                                  track_name  rank        date  \
# 0                        #BrooklynBloodPop!     7  2021-05-17
# 1                        #BrooklynBloodPop!     5  2021-05-24
# 2                        #BrooklynBloodPop!    11  2021-05-31
# 3                        #BrooklynBloodPop!    13  2021-06-07
# 4                        #BrooklynBloodPop!    16  2021-06-14
# 5                        #BrooklynBloodPop!    18  2021-06-21
# 6                        #BrooklynBloodPop!    39  2021-06-28
# 7                        #BrooklynBloodPop!    36  2021-07-05
# 8                        #BrooklynBloodPop!    46  2021-07-12
# 9                                  #Natural    22  2018-01-08
# 10                                 #Natural    12  2018-01-15
# 11                                 #Natural    27  2018-01-22
# 12                              #WIPEITDOWN    43  2020-06-08
# 13            #Ysya2020 Vol. 1 - Una de Dos    32  2020-07-13
# 14           #Ysya2020 Vol. 4 - Pasa Que Yo    28  2020-11-02
# 15              #Ysya2020 Vol. 5 - Silbando    43  2020-11-16
# 16    #Ysya2020 Vol. 6 - Un Flow de Infarto    22  2020-11-16
# 17                                      $$$    42  2018-05-07
# 18                   (It Happens) Sometimes    25  2018-09-24
# 19  (You Make Me Feel Like) A Natural Woman    31  2018-08-20
# 20                (no me despegues tu boca)    49  2020-04-27
# 21                                        +    25  2020-01-13
# 22                                        +    25  2020-01-20
# 23                                        +    44  2020-01-27
# 24                                        +    46  2020-02-17
# 25                                        +    42  2020-02-24
# 26                                        +    50  2020-03-02
# 27                                        +    49  2020-03-09
# 28                         ...Ready For It?     1  2017-09-04
# 29                         ...Ready For It?    10  2017-09-11
#
#                  artist_name     region chart_type position_change  \
# 0                       SyKo  Argentina    viral50   SAME_POSITION
# 1                       SyKo  Argentina    viral50         MOVE_UP
# 2                       SyKo  Argentina    viral50       MOVE_DOWN
# 3                       SyKo  Argentina    viral50       MOVE_DOWN
# 4                       SyKo  Argentina    viral50       MOVE_DOWN
# 5                       SyKo  Argentina    viral50       MOVE_DOWN
# 6                       SyKo  Argentina    viral50       MOVE_DOWN
# 7                       SyKo  Argentina    viral50       MOVE_DOWN
# 8                       SyKo  Argentina    viral50       MOVE_DOWN
# 9           Paty Cantú, Juhn  Argentina    viral50   SAME_POSITION
# 10          Paty Cantú, Juhn  Argentina    viral50   SAME_POSITION
# 11          Paty Cantú, Juhn  Argentina    viral50       MOVE_DOWN
# 12                 BMW KENNY  Argentina    viral50       NEW_ENTRY
# 13          YSY A, CLUB HATS  Argentina    viral50       NEW_ENTRY
# 14           YSY A, Yesan 雪山  Argentina    viral50       NEW_ENTRY
# 15          YSY A, CLUB HATS  Argentina    viral50       NEW_ENTRY
# 16           YSY A, Bizarrap  Argentina    viral50       NEW_ENTRY
# 17                  (G)I-DLE  Argentina    viral50       NEW_ENTRY
# 18                 Jack Back  Argentina    viral50       NEW_ENTRY
# 19           Aretha Franklin  Argentina    viral50         MOVE_UP
# 20             Covi Quintana  Argentina    viral50       NEW_ENTRY
# 21  Aitana, Cali Y El Dandee  Argentina    viral50       NEW_ENTRY
# 22  Aitana, Cali Y El Dandee  Argentina    viral50         MOVE_UP
# 23  Aitana, Cali Y El Dandee  Argentina    viral50       MOVE_DOWN
# 24  Aitana, Cali Y El Dandee  Argentina    viral50       NEW_ENTRY
# 25  Aitana, Cali Y El Dandee  Argentina    viral50       MOVE_DOWN
# 26  Aitana, Cali Y El Dandee  Argentina    viral50       MOVE_DOWN
# 27  Aitana, Cali Y El Dandee  Argentina    viral50   SAME_POSITION
# 28              Taylor Swift  Argentina    viral50       NEW_ENTRY
# 29              Taylor Swift  Argentina    viral50       MOVE_DOWN
#
#     weeks_on_chart  peak_position  previous_rank     source_type  \
# 0                9              5            NaN  charts_viral50
# 1                9              5            7.0  charts_viral50
# 2                9              5            5.0  charts_viral50
# 3                9              5           11.0  charts_viral50
# 4                9              5           13.0  charts_viral50
# 5                9              5           16.0  charts_viral50
# 6                9              5           18.0  charts_viral50
# 7                9              5           39.0  charts_viral50
# 8                9              5           36.0  charts_viral50
# 9                3             12            NaN  charts_viral50
# 10               3             12           22.0  charts_viral50
# 11               3             12           12.0  charts_viral50
# 12               1             43            NaN  charts_viral50
# 13               1             32            NaN  charts_viral50
# 14               1             28            NaN  charts_viral50
# 15               1             43            NaN  charts_viral50
# 16               1             22            NaN  charts_viral50
# 17               1             42            NaN  charts_viral50
# 18               1             25            NaN  charts_viral50
# 19               1             31            NaN  charts_viral50
# 20               1             49            NaN  charts_viral50
# 21               7             25            NaN  charts_viral50
# 22               7             25           25.0  charts_viral50
# 23               7             25           25.0  charts_viral50
# 24               7             25           44.0  charts_viral50
# 25               7             25           46.0  charts_viral50
# 26               7             25           42.0  charts_viral50
# 27               7             25           50.0  charts_viral50
# 28               2              1            NaN  charts_viral50
# 29               2              1            1.0  charts_viral50
#
#                   track_id
# 0   5tDbyeaCvxjNCBcupQucGo
# 1   5tDbyeaCvxjNCBcupQucGo
# 2   5tDbyeaCvxjNCBcupQucGo
# 3   5tDbyeaCvxjNCBcupQucGo
# 4   5tDbyeaCvxjNCBcupQucGo
# 5   5tDbyeaCvxjNCBcupQucGo
# 6   5tDbyeaCvxjNCBcupQucGo
# 7   5tDbyeaCvxjNCBcupQucGo
# 8   5tDbyeaCvxjNCBcupQucGo
# 9   3y7XIu4NloDcCSekDbCvf6
# 10  3y7XIu4NloDcCSekDbCvf6
# 11  3y7XIu4NloDcCSekDbCvf6
# 12  5qOE3kEU14vcc6OUDkgKkv
# 13  7nFta4LZyL0MTDDqbjiQW2
# 14  7qf15ZBTnAyOZX5UIWrsKj
# 15  6TI490muJ6RgFsYJc626BZ
# 16  2byu6eeLWaBq88ZtusqU4V
# 17  6d8DgvFxp6lbdfOw9BVkLS
# 18  4psxV3oAIDBXKL2oS9KcFq
# 19  5K09WxKdlkroDyEVyOSySy
# 20  2j0KnNhlO9lY1EWPOkblK3
# 21  1MXzojJav1N4cREWTFm1iZ
# 22  1MXzojJav1N4cREWTFm1iZ
# 23  1MXzojJav1N4cREWTFm1iZ
# 24  1MXzojJav1N4cREWTFm1iZ
# 25  1MXzojJav1N4cREWTFm1iZ
# 26  1MXzojJav1N4cREWTFm1iZ
# 27  1MXzojJav1N4cREWTFm1iZ
# 28  2yLa0QULdQr0qAIvVwN6B5
# 29  2yLa0QULdQr0qAIvVwN6B5
