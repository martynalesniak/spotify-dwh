# %%
from extract.extract import *
import pandas as pd

# %%
output = extract_multiple_sources(
    [r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\radio.csv'],
    r'.\output',
    enrich=True
)
# Out:
# Processed 0/30 tracks for Spotify enrichment
# Processed 10/30 tracks for Spotify enrichment
# Processed 20/30 tracks for Spotify enrichment
# Skipping MusicBrainz enrichment for cached artist: Vanilla Ice
# Skipping MusicBrainz enrichment for cached artist: Janet Jackson
# Skipping MusicBrainz enrichment for cached artist: Mariah Carey
# Skipping MusicBrainz enrichment for cached artist: Pebbles
# Skipping MusicBrainz enrichment for cached artist: James Ingram
# Artist not found for M.C. Hammer
# Skipping MusicBrainz enrichment for cached artist: After 7
# Skipping MusicBrainz enrichment for cached artist: Alias
# Skipping MusicBrainz enrichment for cached artist: INXS
# Skipping MusicBrainz enrichment for cached artist: Warrant
# Skipping MusicBrainz enrichment for cached artist: Candyman
# Skipping MusicBrainz enrichment for cached artist: Deee-Lite
# Skipping MusicBrainz enrichment for cached artist: Maxi Priest
# Skipping MusicBrainz enrichment for cached artist: Black Box
# ...

# %%
processed_data = pd.read_csv(r'.\output\raw_radio_20250604_170744.csv')

# %%
processed_data
# Out:
#           date                                    track_name  \
# 0   1990-10-31                                  Ice Ice Baby
# 1   1990-10-31                                     Black Cat
# 2   1990-10-31                               Love Takes Time
# 3   1990-10-31                        Giving You The Benefit
# 4   1990-10-31                        I Don't Have The Heart
# 5   1990-10-31                                          Pray
# 6   1990-10-31                                    Can't Stop
# 7   1990-10-31                       More Than Words Can Say
# 8   1990-10-31                                Suicide Blonde
# 9   1990-10-31                                    Cherry Pie
# 10  1990-10-31                                Knockin' Boots
# 11  1990-10-31                        Groove Is In The Heart
# 12  1990-10-31                                  Close To You
# 13  1990-10-31                           Everybody Everybody
# ...

# %%
processed = ChartPreporcessor().transform(processed_data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 processed = ChartPreporcessor().transform(processed_data)
#
# NameError: name 'ChartPreporcessor' is not defined
