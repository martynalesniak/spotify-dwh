# %%
from extract.extract import *
import pandas as pd

# %%
output = extract_multiple_sources(
    [r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\streaming_songs.csv'],
    r'.\output',
    enrich=True
)
# Out:
# Processed 0/50 tracks for Spotify enrichment
# Processed 10/50 tracks for Spotify enrichment
# Processed 20/50 tracks for Spotify enrichment
# Processed 30/50 tracks for Spotify enrichment
# Processed 40/50 tracks for Spotify enrichment
# Skipping MusicBrainz enrichment for cached artist: 1QRj3hoop9Mv5VvHQkwPEp
# Skipping MusicBrainz enrichment for cached artist: 0du5cEVh5yTK9QJze8zA0C
# Skipping MusicBrainz enrichment for cached artist: 5pKCCKE2ajJHZ9KAiaK11H
# Skipping MusicBrainz enrichment for cached artist: 16oZKvXb6WkQlVAjwo2Wbg
# Skipping MusicBrainz enrichment for cached artist: 53XhwfbYqKCa1cC15pYq2q
# Skipping MusicBrainz enrichment for cached artist: 5yDFnbgbAd2nQMLy7OY0vl
# Skipping MusicBrainz enrichment for cached artist: 2YZyLoL8N0Wb9xBt1NhZWg
# Skipping MusicBrainz enrichment for cached artist: 085pc2PYOi8bGKj0PNjekA
# Skipping MusicBrainz enrichment for cached artist: 7v49oVVUhvIQG5EK0jkcF7
# Skipping MusicBrainz enrichment for cached artist: 5nCi3BB41mBaMH9gfr6Su0
# ...

# %%
processed_data = pd.read_csv(r'.\output\raw_streaming_songs_20250604_190905.csv')
processed_data2 = pd.read_csv(r'.\output\raw_streaming_songs_20250604_191036.csv')

# %%
processed_data.head(2)
# Out:
#          date            track_name     artist_name  rank  Last Week  \
# 0  2013-01-23       Root Beer Float  Olivia O'Brien     1          1
# 1  2013-01-23  Locked out of Heaven      Bruno Mars     2          2
#
#    peak_position weeks_on_chart  \
# 0              1              -
# 1              1              -
#
#                                            Image URL      source_type  \
# 0  https://charts-static.billboard.com/img/2012/0...  streaming_songs
# 1  https://charts-static.billboard.com/img/2012/1...  streaming_songs
#
#          spotify_track_id  duration  explicit               artist_id genres  \
# 0  3bA30uvYoSwHYFW4IOO2O4   193.746     False  1QRj3hoop9Mv5VvHQkwPEp     []
# 1  3w3y8KPTfNeOKPiqUTakBh   233.478     False  0du5cEVh5yTK9QJze8zA0C     []
#
#    artist_count release_date        country    type
# 0             2   2016-09-16            NaN     NaN
# 1             1   2012-12-07  United States  Person

# %%
processed_data2.head(2)
# Out:
#          date            track_name                             artist_name  \
# 0  2013-01-23           Thrift Shop  Macklemore & Ryan Lewis Featuring Wanz
# 1  2013-01-23  Locked Out Of Heaven                              Bruno Mars
#
#    rank  Last Week  peak_position weeks_on_chart  \
# 0     1          1              1              -
# 1     2          2              1              -
#
#                                            Image URL      source_type  \
# 0  https://charts-static.billboard.com/img/2012/0...  streaming_songs
# 1  https://charts-static.billboard.com/img/2012/1...  streaming_songs
#
#                  track_id               artist_id
# 0  3bA30uvYoSwHYFW4IOO2O4  1QRj3hoop9Mv5VvHQkwPEp
# 1  3w3y8KPTfNeOKPiqUTakBh  0du5cEVh5yTK9QJze8zA0C
