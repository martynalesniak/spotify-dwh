# %%
from extract.extract import *
import pandas as pd

# %%
billboard = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\billboard200.csv')
hot100 = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\hot100.csv')
# Out:
# C:\Users\marty\AppData\Local\Temp\ipykernel_17764\782904980.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   billboard = pd.read_csv(r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\billboard200.csv')

# %%
output = extract_multiple_sources(
    [r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\billboard200.csv',
     r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\radio.csv',
     r'C:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\data\charts.csv'],
    r'.\output',
    enrich=True
)
# Out:
# c:\Users\marty\OneDrive\Pulpit\studia\sem6\hurtownie\spotify-dwh\etl\extract\extract.py:159: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(file_path).head(limit)
# Processed 0/30 tracks for Spotify enrichment
# Processed 10/30 tracks for Spotify enrichment
# Processed 20/30 tracks for Spotify enrichment
# No tracks found for Oldies But Goodies; Vol. 5 - Various Artists
# Artist not found for Ann-Margret
# Artist not found for Bobby "Blue" Bland
# Artist not found for Mos Def
# Artist not found for Frank Fontaine
# Data saved to .\output\raw_billboard200_20250604_092416.csv, records: 29
# Processed 0/30 tracks for Spotify enrichment
# Processed 10/30 tracks for Spotify enrichment
# Processed 20/30 tracks for Spotify enrichment
# Artist not found for Deee-Lite
# Artists not found.
# Data saved to .\output\raw_radio_20250604_092525.csv, records: 30
# Processed 0/30 tracks for Spotify enrichment
# ...

# %%
processed_data = pd.read_csv(r'.\output\raw_charts_20250604_092903.csv')

# %%
processed_data
# Out:
#                                  track_name  rank        date  \
# 0                   Chantaje (feat. Maluma)     1  2017-01-01
# 1               Vente Pa' Ca (feat. Maluma)     2  2017-01-01
# 2                Reggaetón Lento (Bailemos)     3  2017-01-01
# 3                                    Safari     4  2017-01-01
# 4                               Shaky Shaky     5  2017-01-01
# 5                               Traicionera     6  2017-01-01
# 6                   Cuando Se Pone a Bailar     7  2017-01-01
# 7                 Otra vez (feat. J Balvin)     8  2017-01-01
# 8                              La Bicicleta     9  2017-01-01
# 9                    Dile Que Tu Me Quieres    10  2017-01-01
# 10                       Andas En Mi Cabeza    11  2017-01-01
# 11           Desde Esa Noche (feat. Maluma)    12  2017-01-01
# 12                           Borro Cassette    13  2017-01-01
# 13          Gyal You a Party Animal - Remix    14  2017-01-01
# ...
