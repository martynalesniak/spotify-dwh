# %%
from extract.extract import *
import pandas as pd

# %%
billboard = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard200.csv')
hot100 = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\hot100.csv')
# Out:
# C:\Users\ulasz\AppData\Local\Temp\ipykernel_30260\6462556.py:1: DtypeWarning: Columns (4) have mixed types. Specify dtype option on import or set low_memory=False.
#   billboard = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard200.csv')

# %%
billboard_small = billboard.head(5)
billboard_small.to_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard_small.csv', index=False)

# %%
output = extract_multiple_sources(
    [r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\billboard_small.csv'],
    r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane',
    enrich=True
)
# Out:
# Spotify client initialized with ID: 256fc9a30fa84a3da8fb51c8722a7463
# Spotify client initialized with secret: 50703503822742349e532c5957f804ae
# Processed 0/5 tracks for Spotify enrichment
# Data saved to C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\raw_billboard_small_20250603_201345.csv, records: 5

# %%
processed_data = pd.read_csv(r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\raw_billboard_small_20250603_201345.csv')

# %%
processed_data
# Out:
#          date                                         track_name  \
# 0  1963-08-14                             Days of Wine and Roses
# 1  1963-08-14  Drown In My Own Tears - Live At The Regal Thea...
# 2  1963-08-14                    West Side Story: Act I: America
# 3  1963-08-14                             Puff, the Magic Dragon
# 4  1963-08-14  If You Wanna Be Happy (aka If You Want to Be H...
#
#             artist_name  rank  Last Week  peak_position weeks_on_chart  \
# 0         Andy Williams     1          1              1              -
# 1         Stevie Wonder     2          2              1              -
# 2     Leonard Bernstein     3          3              1              -
# 3  Peter, Paul and Mary     4          4              1              -
# 4           Trini Lopez     5          5              1              -
#
#                                            Image URL      source_type  \
# 0  https://charts-static.billboard.com/img/1963/0...  billboard_small
# ...

# %%
billboard_small
# Out:
#          Date                                         Song  \
# 0  1963-08-14                       Days Of Wine And Roses
# 1  1963-08-14  Little Stevie Wonder/The 12 Year Old Genius
# 2  1963-08-14                              West Side Story
# 3  1963-08-14                                     (Moving)
# 4  1963-08-14                          Trini Lopez At PJ's
#
#                Artist  Rank Last Week  Peak Position Weeks in Charts  \
# 0       Andy Williams     1         1              1               -
# 1       Stevie Wonder     2         2              1               -
# 2          Soundtrack     3         3              1               -
# 3  Peter| Paul & Mary     4         4              1               -
# 4         Trini Lopez     5         5              1               -
#
#                                            Image URL
# 0  https://charts-static.billboard.com/img/1963/0...
# 1  https://charts-static.billboard.com/img/1963/0...
# ...
