# %%
from extract.extract import *
import pandas as pd

# %%
output = extract_multiple_sources(
    [r'C:\Users\ulasz\OneDrive\Pulpit\studia\sem6\hurtownie danych\dane\charts_viral50.csv'],
    r'.\output',
    enrich=True
)
# Out:
# Processed 0/50 tracks for Spotify enrichment
# Processed 10/50 tracks for Spotify enrichment
# Processed 20/50 tracks for Spotify enrichment
# Processed 30/50 tracks for Spotify enrichment
# Processed 40/50 tracks for Spotify enrichment
# Processed 0/17 artists for MusicBrainz enrichment
# Artist not found for Boy Wonder CF
# Processed 10/17 artists for MusicBrainz enrichment
# Artists not found.
# Data saved to .\output\raw_charts_viral50_20250604_213838.csv, records: 50

# %%
processed_data = pd.read_csv(r'.\output\raw_charts_viral50_20250604_213838.csv')
processed_data2 = pd.read_csv(r'.\output\raw_streaming_songs_20250604_191036.csv')

# %%
processed_data
# Out:
#                             track_name  rank        date  \
# 0   Żółte flamastry i grube katechetki   155  2020-06-29
# 1   Żółte flamastry i grube katechetki   169  2020-07-06
# 2   Żółte flamastry i grube katechetki   190  2020-07-13
# 3   Żółte flamastry i grube katechetki   163  2020-07-20
# 4   Żółte flamastry i grube katechetki   162  2020-07-27
# 5   Żółte flamastry i grube katechetki   173  2020-08-03
# 6   Żółte flamastry i grube katechetki   184  2020-08-10
# 7   Żółte flamastry i grube katechetki   188  2020-08-17
# 8   Żółte flamastry i grube katechetki   182  2020-08-24
# 9   Żółte flamastry i grube katechetki   199  2020-09-14
# 10  Żółte flamastry i grube katechetki   127  2021-04-05
# 11  Żółte flamastry i grube katechetki   163  2021-04-12
# 12  Żółte flamastry i grube katechetki   179  2021-04-19
# 13  Żółte flamastry i grube katechetki   196  2021-04-26
# 14  Żółte flamastry i grube katechetki   180  2021-05-03
# ...

# %%
processed_data2.head(2)
# Out:
#          date            track_name                             artist_name  \
# 0  2013-01-23           Thrift Shop  Macklemore & Ryan Lewis Featuring Wanz
# 1  2013-01-23  Locked Out Of Heaven                              Bruno Mars
#
#    rank  Last Week  peak_position weeks_on_chart  \
# 0     1          1              1              -
# 1     2          2              1              -
#
#                                            Image URL      source_type  \
# 0  https://charts-static.billboard.com/img/2012/0...  streaming_songs
# 1  https://charts-static.billboard.com/img/2012/1...  streaming_songs
#
#                  track_id               artist_id
# 0  3bA30uvYoSwHYFW4IOO2O4  1QRj3hoop9Mv5VvHQkwPEp
# 1  3w3y8KPTfNeOKPiqUTakBh  0du5cEVh5yTK9QJze8zA0C
